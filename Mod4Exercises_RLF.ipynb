# %% [markdown]
# # Module 4 Exercises - Data Visualization

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "dvddata.xlsx" file as a dataframe. Then rename the following columns (new column name is in parentheses):
# - \# of Clients (Clients)
# - Visits to each Client per Month (Visits)
# - Calls to each Client per month (Calls)
# - Emails to each Client per month (Emails)
# - \# of businesses in district (Business)

# %%
# Robert Fuss ITI340 06/14/2019
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dir =  "/home/robt/Projects/ITI340_rf/datasets/"
df=pd.read_excel(dir + "dvddata.xlsx")
print(" df shape:\t", df.shape)                      #process control
# Out:
#  df shape:	 (100, 9)

# %%
df01=df.copy()
print(df01.columns)
df01.rename(columns = {'# of Clients':'Clients'}, inplace =True)                         #rename column
df01.rename(columns = {' Visits to each Client per Month' : 'Visits'}, inplace =True)    #rename column
df01.rename(columns = {'Calls to each Client per month' : 'Calls'}, inplace =True)       #rename column
df01.rename(columns = {'Emails to each Client per month' : 'Emails'}, inplace =True)     #rename column
df01.rename(columns = {'# of businesses in district' : 'Business'}, inplace =True)       #rename column
print(df01.columns)
# Out:
# Index(['Salesperson', 'District', 'Region', 'Sales', '# of Clients',
#        ' Visits to each Client per Month', 'Calls to each Client per month',
#        'Emails to each Client per month', '# of businesses in district'],
#       dtype='object')
# Index(['Salesperson', 'District', 'Region', 'Sales', 'Clients', 'Visits',
#        'Calls', 'Emails', 'Business'],
#       dtype='object')

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, use the Seaborn library to create a scatterplot of the number of clients compared to the sales.

# %%
#make a scatterplot
sns.lmplot(x='Clients', y='Sales', data=df01)
plt.title('number of clients compared to the sales')
# Out:
# Text(0.5, 1.0, 'number of clients compared to the sales')

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe in the previous exercise, use the Seaborn library to make a boxplot of the Clients, Visits, Calls, and Emails columns. (**Hint**: Make a dataframe that only contains those columns)

# %%
df02=df01.copy()                                          #copy dataframe
print('original DF: \t', df02.shape)
df02.drop(columns = ['Salesperson', 'District', 'Region', 'Sales', 'Business'], inplace =True)      #delete selected columns
print('edited DF: \t', df02.shape)
sns.boxplot(data=df02);  plt.title('Selected Clients, Visits, Calls, and Emails Data')
plt.show()                                   #display plot -- plot/title commands must immediately be executed before display cmd
sns.boxplot(data=df02);  plt.title('Selected Clients, Visits, Calls, and Emails Data')
plt.savefig('fig01')                         #save plot to file -- plot/title commands must immediately be executed before save cmd
# Out:
# original DF: 	 (100, 9)
# edited DF: 	 (100, 4)

# %% [markdown]
# ### Exercise 4:
#
# Using the dataframe from Exercise 3, use the Seaborn library to make a violin plot of sales per region.

# %%
plt.subplots(figsize=(13,7))      #change size of plot

#violin plot shows the distribution of Sales for each Region
sns.violinplot(x='Region', y='Sales', data=df01);  plt.title('Region Sales')
# plt.show()
sns.violinplot(x='Region', y='Sales', data=df01);  plt.title('Region Sales')
plt.savefig(dir+'fig02')                         #save plot to file -- plot/title commands must immediately be executed before save c

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe in the previous exercise, create a swarm plot of sales per region.

# %%
#create color palette
#color Hex numbers are from Bulbapedia (https://bulbapedia.bulbagarden.net/wiki/Category:Type_color_templates)
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]
#swarm plot
plt.subplots(figsize=(13,7))
sns.swarmplot(x='Region', y='Sales', data=df01, palette=pkmn_type_colors);  plt.title('Swan Plot--Region Sales')
plt.savefig(dir+'fig03')

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a correlation heatmap.

# %%
#  correlation heatmap
#show correlation of stats via heatmap
corr = df01.corr()
plt.subplots(figsize=(13,7))
sns.heatmap(corr, vmin=-1, annot=True);  plt.title('Collelation Heatmap')
plt.savefig(dir+'fig04')         #save plot to file -- plot/title commands must immediately be executed before save

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe in the previous exercise, make a bar chart (count plot) of the regions.

# %%
current_palette = sns.color_palette()                            #Reset color palette
# grn_colors = sns.palplot(sns.color_palette("Greens"))
#create a bar plot of Region frequency
# sns.countplot(x='Region', data=df01, palette=grn_colors);  plt.title('Region Barchart (counts)')
sns.countplot(x='Region', data=df01);  plt.title('Region Barchart (counts)')
plt.xticks(rotation=-0)
plt.savefig(dir+'fig05')

# %% [markdown]
# ### Bonus
#
# Feel free to explore any other data visualizations using the Seaborn library.
